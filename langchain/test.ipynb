# %%
import langchain
langchain.__version__
# Out:
# '1.3.11'

# %%
# Out:
# Deleting old cache from C drive...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[3], line 21
#      19 if os.path.exists(old_cache):
#      20     print("Deleting old cache from C drive...")
# ---> 21     shutil.rmtree(old_cache)
#      22     print("Deleted.")
#      23 else:
#
# File c:\Users\ishua\AppData\Local\Programs\Python\Python311\Lib\shutil.py:787, in rmtree(path, ignore_errors, onerror, dir_fd)
#     785     # can't continue even if onerror hook returns
#     786     return
# --> 787 return _rmtree_unsafe(path, onerror)
#
# File c:\Users\ishua\AppData\Local\Programs\Python\Python311\Lib\shutil.py:629, in _rmtree_unsafe(path, onerror)
#     627         onerror(os.path.islink, fullname, sys.exc_info())
#     628         continue
# --> 629     _rmtree_unsafe(fullname, onerror)
#     630 else:
#     631     try:
#
# ...
